# %% [markdown]
# # Choice under risk and ambiguity task
#
# Levy, I., Snell, J., Nelson, A. J., Rustichini, A., & Glimcher, P. W. (2010). Neural Representation of Subjective Value Under Risk and Ambiguity. *Journal of Neurophysiology, 103*(2), 1036-1047.
#
# <center>
#     <img src="./images/cra.png" style="max-width: 500px">
# </center>

# %% [markdown]
# ## Task definition
#
# - **Design variables**
#     - **`p_var` ($p_V$)**: the probability to win the reward of the variable option
#         - Fixed to 0.5 for ambiguous trials
#     - **`a_var` ($A_V$)**: the level of ambiguity of the variable option
#         - Fixed to 0 for risky trials
#     - **`r_var` ($R_V$)**: the amount of reward of the variable option
#     - **`r_fix` ($R_F$)**: the amount of reward of the fixed option
# - **Possible responses**: `0` (fixed option), `1` (variable option)

# %%
from adopy.tasks.cra import TaskCRA

task = TaskCRA()

# %%
task.name
# Out:
# 'Choice under risk and ambiguity task'

# %%
task.designs
# Out:
# ['p_var', 'a_var', 'r_var', 'r_fix']

# %%
task.responses
# Out:
# ['choice']

# %% [markdown]
# ## Model definition - Linear model
#
# $$
# \begin{aligned}
#     U_F &= 0.5 \cdot (R_F) ^\alpha \\
#     U_V &= \left[ p_V - \beta \cdot \frac{A_V}{2} \right] \cdot (R_V) ^\alpha \\
#     P(V\, over \, F) &= \frac{1}{1 + \exp [\gamma (U_F - U_V)]}
# \end{aligned}
# $$
#
# - **Model parameters**
#     - **`alpha` ($\alpha$)**: risk attitude parameter
#     - **`beta` ($\beta$)**: ambiguity attitude parameter
#     - **`gamma` ($\gamma$)**: inverse temperature

# %%
from adopy.tasks.cra import ModelLinear

model = ModelLinear()

# %%
model.name
# Out:
# 'Linear model for the CRA task'

# %%
model.params
# Out:
# ['alpha', 'beta', 'gamma']

# %% [markdown]
# ## Grid definition

# %% [markdown]
# ### Grid for design variables

# %%
import numpy as np

# Rewards
r_var = [5, 9.5, 18, 26, 34, 50, 65, 95, 131, 181, 250]
r_fix = [5, 7, 10, 13, 18, 25, 34, 48, 66, 91, 125]

rewards = np.array([
    [rv, rf] for rv in r_var for rf in r_fix if rv > rf
])

# Prob & Ambig (Risky trials)
p_var_risky = [.13, .25, .38]
pa_risky = np.array([[pr, 0] for pr in p_var_risky])

# Prob & Ambig (Ambiguous trials)
a_var_ambig = [.25, .5, .75]
pa_ambig = np.array([[0.5, am] for am in a_var_ambig])

# Prob & Ambig
pr_am = np.vstack([pa_risky, pa_ambig])

grid_design = {('p_var', 'a_var'): pr_am, ('r_var', 'r_fix'): rewards}

# %% [markdown]
# ### Grid for model parameters

# %%
grid_param = {
    'alpha': np.linspace(0, 3, 11)[1:],
    'beta': np.linspace(-3, 3, 11),
    'gamma': np.linspace(0, 5, 11)[1:]
}

# %% [markdown]
# ### Grid for response variables

# %%
grid_response = {
    'choice': [0, 1]
}

# %% [markdown]
# ### Engine initialization

# %%
from adopy import Engine

engine = Engine(task, model, grid_design, grid_param, grid_response)
# Out:
# ent (462, 1100)
# Cond ent: (462,)

# %%
# Posterior means (alpha, beta, gamma)
engine.post_mean
# Out:
# array([ 1.6499952e+00, -9.3132257e-10,  2.7500153e+00], dtype=float32)

# %% [markdown]
# ## Design comparison
#
# 1. **ADO design**
# 2. **Fixed design**, used by Levy et al. (2010)
# 3. **Random design**

# %%
N_TRIAL = 60

# %% [markdown]
# ### Functions
#
# #### Simulate a response

# %%
# True parameter values to simulate responses
PARAM_TRUE = {'alpha': 0.67, 'beta': 0.66, 'gamma': 1.5}

# %%
from scipy.stats import bernoulli

def get_simulated_response(design):
    # Calculate the probability to choose a variable option
    p_var, a_var, r_var, r_fix = (
        design['p_var'], design['a_var'], design['r_var'], design['r_fix']
    )
    alpha, beta, gamma = PARAM_TRUE['alpha'], PARAM_TRUE['beta'], PARAM_TRUE['gamma']
    
    u_fix = 0.5 * np.power(r_fix, alpha)
    u_var = (p_var - beta * a_var / 2) * np.power(r_var, alpha)
    
    p_obs = 1 / (1 + np.exp(-gamma * (u_var - u_fix)))

    # Randomly sample a binary choice response from Bernoulli distribution
    return bernoulli.rvs(p_obs)

# %% [markdown]
# #### Generate design pairs for the fixed design (Levy et al., 2010)

# %%
import pandas as pd

def generate_fixed_designs():
    """Generate design pairs used by Levy et al. (2010)"""
    # Prob & Ambig
    pa_risky = [(.5, a_var) for a_var in [.13, .25, .38]]  # for risky conditions
    pa_ambig = [(p_var, .0) for p_var in [.25, .50, .75]]  # for ambiguous conditions
    pa_var = pa_risky + pa_ambig
    
    # Rewards
    rewards = [(r_var, r_fix) for r_var in [5, 9.5, 18, 34, 65]
                              for r_fix in [5]]

    # Make unique design pairs in a 2d matrix
    designs = [[p_var, a_var, r_var, r_fix] for (p_var, a_var) in pa_var
                                            for (r_var, r_fix) in rewards]

    designs = designs + designs  # Double the design pairs
    np.random.shuffle(designs)  # Shuffle the pairs

    return pd.DataFrame(designs, columns=['p_var', 'a_var', 'r_var', 'r_fix'])

# %%
designs_fixed = generate_fixed_designs()

# %%
designs_fixed.head()
# Out:
#    p_var  a_var  r_var  r_fix
# 0   0.75   0.00    9.5      5
# 1   0.50   0.13   65.0      5
# 2   0.50   0.38    5.0      5
# 3   0.50   0.38    5.0      5
# 4   0.75   0.00   18.0      5

# %% [markdown]
# ### Simulation

# %%
# Make an empty DataFrame to store data
df_simul = pd.DataFrame(
    None, columns=['design_type', 'trial', 'design', 'response',
                   'mean_alpha', 'mean_beta', 'mean_gamma',
                   'sd_alpha', 'sd_beta', 'sd_gamma'])

# Run simulations for three designs
for design_type in ['optimal']:
    # Reset the engine as an initial state
    engine.reset()
    
    for i in range(N_TRIAL):
        # Design selection / optimization
        if design_type == 'optimal':
            design = engine.get_design('optimal')
        elif design_type == 'fixed':
            design = designs_fixed.iloc[i, :]
        else:  # design_type == 'random'
            design = engine.get_design('random')
        
        # Experiment
        response = get_simulated_response(design)
        
        # Bayesian updating
        engine.update(design, response)

        # Save the information for updated posteriors
        df_simul = df_simul.append({
            'design_type': design_type,
            'design': str(design),
            'response': response,
            'trial': i + 1,
            'mean_alpha': engine.post_mean[0],
            'mean_beta': engine.post_mean[1],
            'mean_gamma': engine.post_mean[2],
            'sd_alpha': engine.post_sd[0],
            'sd_beta': engine.post_sd[1],
            'sd_gamma': engine.post_sd[2],
        }, ignore_index=True)

# %%
engine.mll.shape

# %%
engine.grid_design

# %%
df_simul
# Out:
#    design_type trial                                             design  \
# 0      optimal     1  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 1      optimal     2  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 2      optimal     3  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 3      optimal     4  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 4      optimal     5  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 5      optimal     6  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 6      optimal     7  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 7      optimal     8  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 8      optimal     9  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 9      optimal    10  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 10     optimal    11  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 11     optimal    12  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 12     optimal    13  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 13     optimal    14  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 14     optimal    15  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 15     optimal    16  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 16     optimal    17  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 17     optimal    18  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 18     optimal    19  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 19     optimal    20  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 20     optimal    21  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 21     optimal    22  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 22     optimal    23  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 23     optimal    24  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 24     optimal    25  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 25     optimal    26  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 26     optimal    27  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 27     optimal    28  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 28     optimal    29  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 29     optimal    30  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 30     optimal    31  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 31     optimal    32  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 32     optimal    33  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 33     optimal    34  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 34     optimal    35  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 35     optimal    36  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 36     optimal    37  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 37     optimal    38  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 38     optimal    39  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 39     optimal    40  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 40     optimal    41  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 41     optimal    42  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 42     optimal    43  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 43     optimal    44  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 44     optimal    45  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 45     optimal    46  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 46     optimal    47  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 47     optimal    48  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 48     optimal    49  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 49     optimal    50  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 50     optimal    51  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 51     optimal    52  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 52     optimal    53  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 53     optimal    54  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 54     optimal    55  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 55     optimal    56  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 56     optimal    57  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 57     optimal    58  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 58     optimal    59  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
# 59     optimal    60  {'p_var': 0.5, 'a_var': 0.75, 'r_var': 250.0, ...
#
#    response  mean_alpha  mean_beta  mean_gamma  sd_alpha   sd_beta  sd_gamma
# 0         1    1.709795  -1.020222    2.750292  0.848451  1.323232  1.435843
# 1         1    1.719918  -1.031460    2.757694  0.843189  1.319285  1.433627
# 2         1    1.724859  -1.035539    2.761867  0.840578  1.318812  1.432458
# 3         1    1.728004  -1.037584    2.764877  0.838918  1.318920  1.431661
# 4         1    1.730323  -1.038821    2.767236  0.837695  1.319151  1.431063
# 5         1    1.732181  -1.039682    2.769139  0.836712  1.319396  1.430594
# 6         1    1.733753  -1.040334    2.770727  0.835879  1.319626  1.430218
# 7         1    1.735126  -1.040860    2.772075  0.835152  1.319835  1.429911
# 8         1    1.736345  -1.041301    2.773245  0.834502  1.320023  1.429657
# 9         1    1.737445  -1.041679    2.774266  0.833914  1.320191  1.429444
# 10        1    1.738447  -1.042011    2.775166  0.833377  1.320343  1.429262
# 11        1    1.739363  -1.042306    2.775978  0.832884  1.320480  1.429106
# 12        1    1.740213  -1.042571    2.776706  0.832427  1.320605  1.428969
# 13        1    1.741003  -1.042811    2.777359  0.832002  1.320720  1.428849
# 14        1    1.741740  -1.043030    2.777960  0.831605  1.320825  1.428743
# 15        1    1.742427  -1.043234    2.778508  0.831231  1.320923  1.428648
# 16        1    1.743078  -1.043421    2.779015  0.830880  1.321013  1.428563
# 17        1    1.743686  -1.043595    2.779485  0.830548  1.321099  1.428486
# 18        1    1.744271  -1.043761    2.779918  0.830232  1.321177  1.428415
# 19        1    1.744818  -1.043914    2.780322  0.829933  1.321251  1.428350
# 20        1    1.745344  -1.044060    2.780701  0.829648  1.321322  1.428291
# 21        1    1.745842  -1.044199    2.781050  0.829378  1.321388  1.428236
# 22        1    1.746321  -1.044331    2.781383  0.829118  1.321450  1.428185
# 23        1    1.746772  -1.044456    2.781700  0.828870  1.321510  1.428137
# 24        1    1.747214  -1.044576    2.781986  0.828630  1.321567  1.428094
# 25        1    1.747631  -1.044690    2.782266  0.828401  1.321622  1.428051
# 26        1    1.748034  -1.044802    2.782534  0.828181  1.321674  1.428013
# 27        1    1.748420  -1.044909    2.782786  0.827969  1.321724  1.427976
# 28        1    1.748794  -1.045012    2.783019  0.827764  1.321773  1.427942
# 29        1    1.749152  -1.045109    2.783251  0.827567  1.321819  1.427909
# 30        1    1.749504  -1.045207    2.783463  0.827376  1.321863  1.427877
# 31        1    1.749842  -1.045298    2.783669  0.827192  1.321906  1.427848
# 32        1    1.750162  -1.045388    2.783874  0.827014  1.321948  1.427820
# 33        1    1.750482  -1.045478    2.784052  0.826840  1.321988  1.427794
# 34        1    1.750788  -1.045564    2.784235  0.826671  1.322028  1.427768
# 35        1    1.751086  -1.045645    2.784403  0.826509  1.322066  1.427745
# 36        1    1.751373  -1.045727    2.784572  0.826351  1.322103  1.427721
# 37        1    1.751655  -1.045806    2.784732  0.826196  1.322139  1.427699
# 38        1    1.751926  -1.045883    2.784884  0.826046  1.322175  1.427678
# 39        1    1.752195  -1.045958    2.785030  0.825900  1.322209  1.427657
# 40        1    1.752450  -1.046033    2.785177  0.825759  1.322243  1.427638
# 41        1    1.752700  -1.046103    2.785299  0.825621  1.322275  1.427619
# 42        1    1.752944  -1.046174    2.785437  0.825486  1.322307  1.427601
# 43        1    1.753187  -1.046243    2.785556  0.825355  1.322339  1.427584
# 44        1    1.753420  -1.046311    2.785696  0.825225  1.322369  1.427567
# 45        1    1.753649  -1.046377    2.785810  0.825100  1.322400  1.427551
# 46        1    1.753873  -1.046441    2.785921  0.824978  1.322429  1.427536
# 47        1    1.754090  -1.046507    2.786034  0.824857  1.322458  1.427521
# 48        1    1.754301  -1.046569    2.786143  0.824741  1.322487  1.427507
# 49        1    1.754511  -1.046629    2.786254  0.824625  1.322514  1.427493
# 50        1    1.754713  -1.046690    2.786354  0.824513  1.322542  1.427480
# 51        1    1.754913  -1.046748    2.786448  0.824404  1.322568  1.427466
# 52        1    1.755107  -1.046808    2.786536  0.824296  1.322594  1.427454
# 53        1    1.755297  -1.046865    2.786636  0.824190  1.322621  1.427441
# 54        1    1.755485  -1.046922    2.786733  0.824087  1.322646  1.427430
# 55        1    1.755667  -1.046976    2.786810  0.823986  1.322671  1.427418
# 56        1    1.755847  -1.047032    2.786891  0.823886  1.322696  1.427407
# 57        1    1.756025  -1.047084    2.786978  0.823789  1.322720  1.427396
# 58        1    1.756203  -1.047139    2.787054  0.823694  1.322745  1.427386
# 59        1    1.756368  -1.047190    2.787141  0.823600  1.322768  1.427376

# %% [markdown]
# ### Results

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

fig, ax = plt.subplots(1, 3, figsize = [15, 4])

# Draw black dotted lines for true parameters
for i, param in enumerate(['alpha', 'beta', 'gamma']):
    ax[i].axhline(PARAM_TRUE[param], color='black', linestyle=':')

for i, design_type in enumerate(['optimal', 'staircase', 'random']):
    df_cond = df_simul.loc[df_simul['design_type'] == design_type]
    line_color = ['blue', 'green', 'red'][i]
    ax = df_cond.plot(x='trial', y=['mean_alpha', 'mean_beta', 'mean_gamma'], ax=ax,
                      subplots=True, figsize=(15, 4), legend=False, color = line_color, alpha = 0.7)

# Set titles and limits on y axes.
ax[0].set_title('$\\alpha$ (Risk attitude)');        ax[0].set_ylim(0, 3)
ax[1].set_title('$\\beta$ (Ambiguity attitude)');    ax[1].set_ylim(-3, 3)
ax[2].set_title('$\\gamma$ (Inverse temperature)');  ax[2].set_ylim(0, 5)

ax[0].legend(['True value', 'ADO', 'Fixed', 'Random'])
ax[1].legend(['True value', 'ADO', 'Fixed', 'Random'])
ax[2].legend(['True value', 'ADO', 'Fixed', 'Random'])

plt.show()

# %% [markdown]
# ## References
#
# Levy, I., Snell, J., Nelson, A. J., Rustichini, A., & Glimcher, P. W. (2010). Neural Representation of Subjective Value Under Risk and Ambiguity. Journal of Neurophysiology, 103 (2), 1036-1047.
